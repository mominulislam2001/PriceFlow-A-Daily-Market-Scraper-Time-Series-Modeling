# %%
import pandas as pd
import numpy 
import os
import glob

# %%
from comodities_exploration import basic_statistics
from comodities_exploration import get_folder_commodities_list
from comodities_exploration import visualize_trends,load_folder_dataframe_in_dictionary

# %%
oil_name_list = get_folder_commodities_list('./cleaned_product_wise_data/Oil')

# %%
oil_df_dict  = load_folder_dataframe_in_dictionary('./cleaned_product_wise_data/Oil')
visualize_trends(oil_df_dict, oil_name_list,'retail')
