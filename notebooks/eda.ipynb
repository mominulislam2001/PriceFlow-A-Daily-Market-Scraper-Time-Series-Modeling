# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
df = pd.read_csv('./cleaned_product_wise_data/onion_local.csv',parse_dates=['date'])

# %%
df.set_index('date',inplace=True)

# %%
df
# Out:
#            product_group product_name_desc unit_retail retail_price_range_tk  \
# date
# 2020-01-02        Spices     Onion (local)    Kilogram              109--117
# 2020-01-04        Spices     Onion (local)    Kilogram                35--40
# 2020-01-05        Spices     Onion (local)    Kilogram              133--142
# 2020-01-06        Spices     Onion (local)    Kilogram              126--136
# 2020-01-07        Spices     Onion (local)    Kilogram              126--136
# ...                  ...               ...         ...                   ...
# 2022-08-25        Spices     Onion (local)    Kilogram                42--46
# 2022-08-29        Spices     Onion (local)    Kilogram                41--45
# 2022-08-30        Spices     Onion (local)    Kilogram                41--44
# 2022-08-31        Spices     Onion (local)    Kilogram                40--44
# 2022-09-01        Spices     Onion (local)    Kilogram                40--43
#
# ...

# %%
from clean_data import clean_product_dataset

# %%
df = clean_product_dataset('./cleaned_product_wise_data/onion_local.csv')

# %%
df
# Out:
#            product_group product_name_desc unit_retail  min_retail_price  \
# 2020-01-02        Spices     Onion (local)    Kilogram             109.0
# 2020-01-03        Spices     Onion (local)    Kilogram               NaN
# 2020-01-04        Spices     Onion (local)    Kilogram              35.0
# 2020-01-05        Spices     Onion (local)    Kilogram             133.0
# 2020-01-06        Spices     Onion (local)    Kilogram             126.0
# ...                  ...               ...         ...               ...
# 2022-08-28        Spices     Onion (local)    Kilogram               NaN
# 2022-08-29        Spices     Onion (local)    Kilogram              41.0
# 2022-08-30        Spices     Onion (local)    Kilogram              41.0
# 2022-08-31        Spices     Onion (local)    Kilogram              40.0
# 2022-09-01        Spices     Onion (local)    Kilogram              40.0
#
#             max_retail_price  avg_retail_price unit_wholesale  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 974 entries, 2020-01-02 to 2022-09-01
# Freq: D
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_group        974 non-null    object
#  1   product_name_desc    974 non-null    object
#  2   unit_retail          974 non-null    object
#  3   min_retail_price     715 non-null    float64
#  4   max_retail_price     715 non-null    float64
#  5   avg_retail_price     715 non-null    float64
#  6   unit_wholesale       974 non-null    object
#  7   min_wholesale_price  715 non-null    float64
#  8   max_wholesale_price  715 non-null    float64
#  9   avg_wholesale_price  715 non-null    float64
# dtypes: float64(6), object(4)
# memory usage: 83.7+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 974 entries, 2020-01-02 to 2022-09-01
# Freq: D
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_group        974 non-null    object
#  1   product_name_desc    974 non-null    object
#  2   unit_retail          974 non-null    object
#  3   min_retail_price     715 non-null    float64
#  4   max_retail_price     715 non-null    float64
#  5   avg_retail_price     715 non-null    float64
#  6   unit_wholesale       974 non-null    object
#  7   min_wholesale_price  715 non-null    float64
#  8   max_wholesale_price  715 non-null    float64
#  9   avg_wholesale_price  715 non-null    float64
# dtypes: float64(6), object(4)
# memory usage: 83.7+ KB

# %%
import matplotlib.pyplot as plt

# %%
# Plot retail prices
plt.figure(figsize=(14, 7))

plt.subplot(2, 1, 1)
plt.plot(df.index, df['min_retail_price'], label='Min Retail Price')
plt.plot(df.index, df['max_retail_price'], label='Max Retail Price')
plt.plot(df.index, df['avg_retail_price'], label='Avg Retail Price')
plt.xlabel('Date')
plt.ylabel('Retail Price (Kilogram)')
plt.title('Retail Prices Over Time')
plt.legend()

# Plot wholesale prices
plt.subplot(2, 1, 2)
plt.plot(df.index, df['min_wholesale_price'], label='Min Wholesale Price')
plt.plot(df.index, df['max_wholesale_price'], label='Max Wholesale Price')
plt.plot(df.index, df['avg_wholesale_price'], label='Avg Wholesale Price')
plt.xlabel('Date')
plt.ylabel('Wholesale Price (Quintal)')
plt.title('Wholesale Prices Over Time')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots
# Create traces for retail prices
retail_trace_min = go.Scatter(x=df.index, y=df['min_retail_price'], mode='lines+markers', name='Min Retail Price')
retail_trace_max = go.Scatter(x=df.index, y=df['max_retail_price'], mode='lines+markers', name='Max Retail Price')
retail_trace_avg = go.Scatter(x=df.index, y=df['avg_retail_price'], mode='lines+markers', name='Avg Retail Price')


# Create subplots
fig = make_subplots(rows=2, cols=1, shared_xaxes=True, subplot_titles=('Retail Prices Over Time', 'Wholesale Prices Over Time'))

# Add traces to the subplots for retail prices
fig.add_trace(retail_trace_min, row=1, col=1)
fig.add_trace(retail_trace_max, row=1, col=1)
fig.add_trace(retail_trace_avg, row=1, col=1)


# Show plot
fig.show()

# %%
clean_df
# Out:
#            product_group product_name_desc unit_retail  min_retail_price  \
# date
# 2020-01-02        Spices     Onion (local)    Kilogram               109
# 2020-01-04        Spices     Onion (local)    Kilogram                35
# 2020-01-05        Spices     Onion (local)    Kilogram               133
# 2020-01-06        Spices     Onion (local)    Kilogram               126
# 2020-01-07        Spices     Onion (local)    Kilogram               126
# ...                  ...               ...         ...               ...
# 2022-08-25        Spices     Onion (local)    Kilogram                42
# 2022-08-29        Spices     Onion (local)    Kilogram                41
# 2022-08-30        Spices     Onion (local)    Kilogram                41
# 2022-08-31        Spices     Onion (local)    Kilogram                40
# 2022-09-01        Spices     Onion (local)    Kilogram                40
#
#             max_retail_price  avg_retail_price unit_wholesale  \
# date
# ...
